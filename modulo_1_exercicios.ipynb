# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo 01** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %%
print ('Olá mundo"')
# Out:
# Olá mundo"

# %% [markdown]
# Crie uma célua de texto e adicione uma imagem.

# %% [markdown]
# ![K_Un4flZ_400x400.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# (A)
b = 3
c = 320.52
a = b * c
print (a)
# Out:
# 961.56

# %%
# (B)
a = 834.47
c =119.21
b = a // c
print (b)
# Out:
# 7.0

# %%
# (C)
a = 15378.12
b = 5
c = a /b
print (c)
# Out:
# 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
print('Base referencia:')
print(cancao)
print('------------------------')

print ('Com métodos aplicados:')
print (cancao.title())
print (cancao.split())
print (cancao.upper())
# Out:
# Base referencia:
# Roda mundo, roda gigante, roda moinho, roda pião.
# ------------------------
# Com métodos aplicados:
# Roda Mundo, Roda Gigante, Roda Moinho, Roda Pião.
# ['Roda', 'mundo,', 'roda', 'gigante,', 'roda', 'moinho,', 'roda', 'pião.']
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

# %%
print('Noticia Base')
print (noticia)
print ('-----------------')

print ('Valor Selic')

selic ='2,75%'
print (selic)
print (type(selic))

selic = int(selic [2:7:5])
print(selic)

print ('-----------------')
print ('Valor Ano')

ano ='6'
print (ano)
print (type(ano))

ano = int(ano)
print(ano)
# Out:
# Noticia Base
# Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.
# -----------------
# Valor Selic
# 2,75%
# <class 'str'>
# 7
# -----------------
# Valor Ano
# 6
# <class 'str'>
# 6

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b

print ( b & x)
# Out:
# True
